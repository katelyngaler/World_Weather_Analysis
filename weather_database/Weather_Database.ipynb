# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
#Create Empty City Data list
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create Counters
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#Loop through all the cities in our list
##first try: for i in range(len(cities)):  only gets index, not city name

for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging (if multiple of 50 and greater/equal to 50)
    if (i % 50==0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # create endpoint URL - remove spaces from city name to ensure full name is searched
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    #Run API request
    try:
        #parse the json and retrieve
        city_weather = requests.get(city_url).json()
        #parse data
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        

        #append data
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
        
        #if error skip
        
    except:
        print("City not found. Skipping...")
        pass
    
#indicate data is complete
print("----------------------------")
print("Data Retriecal Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | samarai
# Processing Record 3 of Set 1 | sabang
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | durazno
# Processing Record 9 of Set 1 | phan thiet
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | san cristobal
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | tazovskiy
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | ottawa
# Processing Record 20 of Set 1 | esso
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | morant bay
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | fevik
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | teruel
# Processing Record 30 of Set 1 | bhadrak
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | cidreira
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | canala
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | shenjiamen
# Processing Record 42 of Set 1 | lianran
# Processing Record 43 of Set 1 | port macquarie
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | namibe
# Processing Record 47 of Set 1 | gigmoto
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | broken hill
# Processing Record 1 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 2 | beringovskiy
# Processing Record 3 of Set 2 | waco
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | black river
# Processing Record 7 of Set 2 | faanui
# Processing Record 8 of Set 2 | necochea
# Processing Record 9 of Set 2 | tateyama
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | airai
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | iquique
# Processing Record 14 of Set 2 | taltal
# Processing Record 15 of Set 2 | martapura
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | campbellton
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | bubaque
# Processing Record 20 of Set 2 | ugoofaaru
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | madison
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | lorengau
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | mlyniv
# Processing Record 33 of Set 2 | haysville
# Processing Record 34 of Set 2 | bambari
# Processing Record 35 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 2 | hangu
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | vila velha
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | hofn
# Processing Record 41 of Set 2 | jacmel
# Processing Record 42 of Set 2 | morro bay
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | buchanan
# Processing Record 45 of Set 2 | hami
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | nanchang
# Processing Record 50 of Set 2 | narsaq
# Processing Record 1 of Set 3 | shingu
# Processing Record 2 of Set 3 | husavik
# Processing Record 3 of Set 3 | flinders
# Processing Record 4 of Set 3 | cabo san lucas
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | otane
# Processing Record 10 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 3 | kano
# Processing Record 12 of Set 3 | pangnirtung
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | soyo
# Processing Record 15 of Set 3 | monterey
# Processing Record 16 of Set 3 | wasilla
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | gamba
# Processing Record 20 of Set 3 | pemangkat
# Processing Record 21 of Set 3 | nioro
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | bereda
# Processing Record 25 of Set 3 | brigantine
# Processing Record 26 of Set 3 | viedma
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | cervo
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | wattegama
# Processing Record 31 of Set 3 | jinji
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | lata
# Processing Record 35 of Set 3 | palmer
# Processing Record 36 of Set 3 | muros
# Processing Record 37 of Set 3 | malakal
# Processing Record 38 of Set 3 | brae
# Processing Record 39 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 3 | sikonge
# Processing Record 41 of Set 3 | kulhudhuffushi
# Processing Record 42 of Set 3 | krasnoselkup
# Processing Record 43 of Set 3 | bambanglipuro
# Processing Record 44 of Set 3 | rognedino
# Processing Record 45 of Set 3 | udachnyy
# Processing Record 46 of Set 3 | yelan
# Processing Record 47 of Set 3 | tupik
# Processing Record 48 of Set 3 | kangaatsiaq
# Processing Record 49 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 3 | xiaoweizhai
# Processing Record 1 of Set 4 | muhos
# Processing Record 2 of Set 4 | draguignan
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | acapulco
# Processing Record 5 of Set 4 | forestville
# Processing Record 6 of Set 4 | homer
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | aripuana
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | charlestown
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | vinh
# Processing Record 14 of Set 4 | san matias
# Processing Record 15 of Set 4 | praya
# Processing Record 16 of Set 4 | bang saphan
# Processing Record 17 of Set 4 | myitkyina
# Processing Record 18 of Set 4 | erzin
# Processing Record 19 of Set 4 | olinda
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | port lincoln
# Processing Record 22 of Set 4 | phuthaditjhaba
# Processing Record 23 of Set 4 | rawah
# Processing Record 24 of Set 4 | young
# Processing Record 25 of Set 4 | avarua
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | trat
# Processing Record 28 of Set 4 | sangar
# Processing Record 29 of Set 4 | faya
# Processing Record 30 of Set 4 | saint-georges
# Processing Record 31 of Set 4 | pokhara
# Processing Record 32 of Set 4 | galle
# Processing Record 33 of Set 4 | ilulissat
# Processing Record 34 of Set 4 | fereydun kenar
# Processing Record 35 of Set 4 | tanout
# Processing Record 36 of Set 4 | walvis bay
# Processing Record 37 of Set 4 | marsa matruh
# Processing Record 38 of Set 4 | poli
# Processing Record 39 of Set 4 | khromtau
# Processing Record 40 of Set 4 | karlskoga
# Processing Record 41 of Set 4 | fort nelson
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | panama city
# Processing Record 46 of Set 4 | bontang
# Processing Record 47 of Set 4 | naze
# Processing Record 48 of Set 4 | santa maria
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 50 of Set 4 | bathsheba
# Processing Record 1 of Set 5 | kotido
# Processing Record 2 of Set 5 | lashio
# Processing Record 3 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 5 | sitka
# Processing Record 5 of Set 5 | salalah
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 5 | tigil
# Processing Record 10 of Set 5 | costinesti
# Processing Record 11 of Set 5 | natchez
# Processing Record 12 of Set 5 | port alfred
# Processing Record 13 of Set 5 | tourlaville
# Processing Record 14 of Set 5 | kupang
# Processing Record 15 of Set 5 | grand gaube
# Processing Record 16 of Set 5 | mayumba
# Processing Record 17 of Set 5 | farafangana
# Processing Record 18 of Set 5 | tuktoyaktuk
# Processing Record 19 of Set 5 | baie-comeau
# Processing Record 20 of Set 5 | avera
# Processing Record 21 of Set 5 | mareeba
# Processing Record 22 of Set 5 | hay river
# Processing Record 23 of Set 5 | river falls
# Processing Record 24 of Set 5 | turbat
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | bluff
# Processing Record 27 of Set 5 | bonnyville
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | alice springs
# Processing Record 32 of Set 5 | hovd
# Processing Record 33 of Set 5 | vanimo
# Processing Record 34 of Set 5 | outjo
# Processing Record 35 of Set 5 | sakakah
# Processing Record 36 of Set 5 | avesta
# Processing Record 37 of Set 5 | norman wells
# Processing Record 38 of Set 5 | sahy
# Processing Record 39 of Set 5 | kochevo
# Processing Record 40 of Set 5 | komsomolskiy
# Processing Record 41 of Set 5 | urengoy
# Processing Record 42 of Set 5 | ostrovskoye
# Processing Record 43 of Set 5 | green river
# Processing Record 44 of Set 5 | coihaique
# Processing Record 45 of Set 5 | nemuro
# Processing Record 46 of Set 5 | meybod
# Processing Record 47 of Set 5 | anadyr
# Processing Record 48 of Set 5 | kigoma
# Processing Record 49 of Set 5 | kodiak
# Processing Record 50 of Set 5 | kloulklubed
# Processing Record 1 of Set 6 | betioky
# Processing Record 2 of Set 6 | san jeronimo
# Processing Record 3 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | bilma
# Processing Record 6 of Set 6 | torbay
# Processing Record 7 of Set 6 | matata
# Processing Record 8 of Set 6 | seoul
# Processing Record 9 of Set 6 | henties bay
# Processing Record 10 of Set 6 | westport
# Processing Record 11 of Set 6 | waingapu
# Processing Record 12 of Set 6 | kourou
# Processing Record 13 of Set 6 | penzance
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | toora-khem
# Processing Record 16 of Set 6 | mattru
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | topolovgrad
# Processing Record 20 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 6 | cotonou
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | bow island
# Processing Record 24 of Set 6 | yellowknife
# Processing Record 25 of Set 6 | vila franca do campo
# Processing Record 26 of Set 6 | bengkulu
# Processing Record 27 of Set 6 | odweyne
# Processing Record 28 of Set 6 | lagoa
# Processing Record 29 of Set 6 | burgeo
# Processing Record 30 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 6 | gumushane
# City not found. Skipping...
# Processing Record 32 of Set 6 | kashi
# Processing Record 33 of Set 6 | abu zabad
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | abu kamal
# Processing Record 36 of Set 6 | salinas
# Processing Record 37 of Set 6 | camacupa
# Processing Record 38 of Set 6 | kormilovka
# Processing Record 39 of Set 6 | pochutla
# Processing Record 40 of Set 6 | lenger
# Processing Record 41 of Set 6 | sioux lookout
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | itarema
# Processing Record 44 of Set 6 | niksar
# Processing Record 45 of Set 6 | sibiti
# Processing Record 46 of Set 6 | palmas
# Processing Record 47 of Set 6 | saint-jerome
# Processing Record 48 of Set 6 | tiksi
# Processing Record 49 of Set 6 | dzhebariki-khaya
# Processing Record 50 of Set 6 | falkoping
# City not found. Skipping...
# Processing Record 1 of Set 7 | xichang
# Processing Record 2 of Set 7 | luanda
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | tual
# Processing Record 5 of Set 7 | bilaspur
# Processing Record 6 of Set 7 | luzhou
# Processing Record 7 of Set 7 | bac lieu
# Processing Record 8 of Set 7 | kysyl-syr
# Processing Record 9 of Set 7 | saldanha
# Processing Record 10 of Set 7 | cortez
# Processing Record 11 of Set 7 | sohag
# Processing Record 12 of Set 7 | boffa
# Processing Record 13 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 7 | erenhot
# Processing Record 15 of Set 7 | kaabong
# Processing Record 16 of Set 7 | sinyavino
# Processing Record 17 of Set 7 | sao joao da barra
# Processing Record 18 of Set 7 | makung
# City not found. Skipping...
# Processing Record 19 of Set 7 | vardo
# Processing Record 20 of Set 7 | port-gentil
# Processing Record 21 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 7 | sept-iles
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | umea
# Processing Record 25 of Set 7 | totness
# Processing Record 26 of Set 7 | mount isa
# Processing Record 27 of Set 7 | panzhihua
# Processing Record 28 of Set 7 | floro
# Processing Record 29 of Set 7 | cap-aux-meules
# Processing Record 30 of Set 7 | acarau
# Processing Record 31 of Set 7 | johnstown
# Processing Record 32 of Set 7 | tautira
# Processing Record 33 of Set 7 | sorong
# Processing Record 34 of Set 7 | mendeleyevo
# Processing Record 35 of Set 7 | mazagao
# Processing Record 36 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 7 | half moon bay
# Processing Record 38 of Set 7 | katherine
# Processing Record 39 of Set 7 | mongo
# Processing Record 40 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 7 | te anau
# Processing Record 42 of Set 7 | geraldton
# Processing Record 43 of Set 7 | fiditi
# Processing Record 44 of Set 7 | rio grande
# Processing Record 45 of Set 7 | liberty
# Processing Record 46 of Set 7 | monrovia
# Processing Record 47 of Set 7 | okakarara
# Processing Record 48 of Set 7 | posse
# Processing Record 49 of Set 7 | chiredzi
# Processing Record 50 of Set 7 | wewak
# Processing Record 1 of Set 8 | mamallapuram
# Processing Record 2 of Set 8 | puri
# Processing Record 3 of Set 8 | barabinsk
# Processing Record 4 of Set 8 | saint-joseph
# Processing Record 5 of Set 8 | rundu
# Processing Record 6 of Set 8 | broome
# Processing Record 7 of Set 8 | esperance
# Processing Record 8 of Set 8 | kingman
# Processing Record 9 of Set 8 | taoudenni
# Processing Record 10 of Set 8 | kisangani
# Processing Record 11 of Set 8 | agapovka
# Processing Record 12 of Set 8 | jiuquan
# Processing Record 13 of Set 8 | shushtar
# Processing Record 14 of Set 8 | mumford
# Processing Record 15 of Set 8 | nanfeng
# Processing Record 16 of Set 8 | mandan
# Processing Record 17 of Set 8 | zahvizdya
# Processing Record 18 of Set 8 | yanam
# Processing Record 19 of Set 8 | zhanjiang
# Processing Record 20 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 8 | xinqing
# Processing Record 22 of Set 8 | rincon
# Processing Record 23 of Set 8 | pembroke
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | ust-nera
# Processing Record 26 of Set 8 | qaqortoq
# Processing Record 27 of Set 8 | oktyabrskiy
# Processing Record 28 of Set 8 | wagar
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 32 of Set 8 | savannah bight
# Processing Record 33 of Set 8 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 34 of Set 8 | egvekinot
# Processing Record 35 of Set 8 | banjar
# Processing Record 36 of Set 8 | dosso
# Processing Record 37 of Set 8 | astoria
# Processing Record 38 of Set 8 | makakilo city
# Processing Record 39 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 8 | praia
# Processing Record 41 of Set 8 | san ramon
# Processing Record 42 of Set 8 | san andres
# Processing Record 43 of Set 8 | santa rosa
# Processing Record 44 of Set 8 | kruisfontein
# Processing Record 45 of Set 8 | utinga
# Processing Record 46 of Set 8 | shelburne
# Processing Record 47 of Set 8 | teya
# Processing Record 48 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | bustonkala
# City not found. Skipping...
# Processing Record 50 of Set 8 | port moresby
# Processing Record 1 of Set 9 | mossendjo
# Processing Record 2 of Set 9 | codrington
# Processing Record 3 of Set 9 | kaeo
# Processing Record 4 of Set 9 | pangody
# Processing Record 5 of Set 9 | riyadh
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | teshie
# Processing Record 8 of Set 9 | yerbogachen
# Processing Record 9 of Set 9 | san juan
# Processing Record 10 of Set 9 | chipinge
# Processing Record 11 of Set 9 | cedar city
# Processing Record 12 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 9 | aklavik
# Processing Record 14 of Set 9 | alofi
# Processing Record 15 of Set 9 | xuddur
# Processing Record 16 of Set 9 | risor
# Processing Record 17 of Set 9 | manggar
# Processing Record 18 of Set 9 | otwock
# Processing Record 19 of Set 9 | diamantina
# Processing Record 20 of Set 9 | chino valley
# Processing Record 21 of Set 9 | vao
# Processing Record 22 of Set 9 | bam
# Processing Record 23 of Set 9 | leshukonskoye
# Processing Record 24 of Set 9 | salinopolis
# Processing Record 25 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 9 | ariano irpino
# Processing Record 27 of Set 9 | rio gallegos
# Processing Record 28 of Set 9 | abu samrah
# Processing Record 29 of Set 9 | maniitsoq
# Processing Record 30 of Set 9 | fougamou
# Processing Record 31 of Set 9 | puerto escondido
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | nicoya
# Processing Record 34 of Set 9 | northam
# Processing Record 35 of Set 9 | pucallpa
# Processing Record 36 of Set 9 | pierre
# Processing Record 37 of Set 9 | hit
# Processing Record 38 of Set 9 | mozarlandia
# Processing Record 39 of Set 9 | san isidro
# Processing Record 40 of Set 9 | tiruchchendur
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | berdigestyakh
# Processing Record 43 of Set 9 | clarence town
# Processing Record 44 of Set 9 | horta
# Processing Record 45 of Set 9 | san joaquin
# Processing Record 46 of Set 9 | tilichiki
# Processing Record 47 of Set 9 | kindu
# Processing Record 48 of Set 9 | enniscorthy
# Processing Record 49 of Set 9 | shitanjing
# Processing Record 50 of Set 9 | belmonte
# Processing Record 1 of Set 10 | najran
# Processing Record 2 of Set 10 | san lawrenz
# Processing Record 3 of Set 10 | radhanpur
# Processing Record 4 of Set 10 | carolina
# Processing Record 5 of Set 10 | tobol
# Processing Record 6 of Set 10 | chimbote
# Processing Record 7 of Set 10 | bhatkal
# Processing Record 8 of Set 10 | arman
# Processing Record 9 of Set 10 | mbandaka
# Processing Record 10 of Set 10 | el alto
# Processing Record 11 of Set 10 | pangai
# Processing Record 12 of Set 10 | todos santos
# Processing Record 13 of Set 10 | bronnoysund
# Processing Record 14 of Set 10 | saiha
# Processing Record 15 of Set 10 | kudahuvadhoo
# Processing Record 16 of Set 10 | lavrentiya
# Processing Record 17 of Set 10 | ternate
# Processing Record 18 of Set 10 | portland
# Processing Record 19 of Set 10 | noyabrsk
# Processing Record 20 of Set 10 | jadu
# Processing Record 21 of Set 10 | nelson bay
# Processing Record 22 of Set 10 | barka kana
# Processing Record 23 of Set 10 | yar-sale
# Processing Record 24 of Set 10 | port hedland
# Processing Record 25 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 10 | osoyoos
# Processing Record 27 of Set 10 | inta
# Processing Record 28 of Set 10 | seredka
# Processing Record 29 of Set 10 | sal rei
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | sechura
# Processing Record 32 of Set 10 | paamiut
# Processing Record 33 of Set 10 | mazamari
# Processing Record 34 of Set 10 | qazvin
# Processing Record 35 of Set 10 | majene
# Processing Record 36 of Set 10 | tshela
# Processing Record 37 of Set 10 | santa vitoria do palmar
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | davila
# Processing Record 40 of Set 10 | puerto madero
# Processing Record 41 of Set 10 | dwarka
# Processing Record 42 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 10 | mataram
# Processing Record 44 of Set 10 | burnie
# Processing Record 45 of Set 10 | puerto quijarro
# Processing Record 46 of Set 10 | tromso
# Processing Record 47 of Set 10 | kaniama
# Processing Record 48 of Set 10 | saint-augustin
# Processing Record 49 of Set 10 | nanga eboko
# Processing Record 50 of Set 10 | sistranda
# Processing Record 1 of Set 11 | kampene
# Processing Record 2 of Set 11 | los llanos de aridane
# Processing Record 3 of Set 11 | kuching
# Processing Record 4 of Set 11 | pisco
# Processing Record 5 of Set 11 | kurilsk
# Processing Record 6 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 11 | dawson
# Processing Record 8 of Set 11 | owando
# Processing Record 9 of Set 11 | atambua
# Processing Record 10 of Set 11 | ratnagiri
# Processing Record 11 of Set 11 | nuuk
# Processing Record 12 of Set 11 | lompoc
# Processing Record 13 of Set 11 | poum
# Processing Record 14 of Set 11 | porto velho
# Processing Record 15 of Set 11 | rocha
# Processing Record 16 of Set 11 | banda aceh
# Processing Record 17 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 11 | barcelos
# Processing Record 19 of Set 11 | denpasar
# Processing Record 20 of Set 11 | aksehir
# Processing Record 21 of Set 11 | asuncion
# Processing Record 22 of Set 11 | pitkyaranta
# Processing Record 23 of Set 11 | araouane
# Processing Record 24 of Set 11 | quchan
# Processing Record 25 of Set 11 | mount gambier
# Processing Record 26 of Set 11 | baykit
# Processing Record 27 of Set 11 | khandbari
# Processing Record 28 of Set 11 | svetlogorsk
# Processing Record 29 of Set 11 | sunrise
# Processing Record 30 of Set 11 | toamua
# City not found. Skipping...
# Processing Record 31 of Set 11 | jijiga
# Processing Record 32 of Set 11 | merauke
# Processing Record 33 of Set 11 | berlevag
# Processing Record 34 of Set 11 | mackay
# Processing Record 35 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 11 | menongue
# Processing Record 37 of Set 11 | nome
# Processing Record 38 of Set 11 | prainha
# Processing Record 39 of Set 11 | raudeberg
# Processing Record 40 of Set 11 | labuhan
# Processing Record 41 of Set 11 | santa lucia
# Processing Record 42 of Set 11 | la llanada
# Processing Record 43 of Set 11 | parabel
# Processing Record 44 of Set 11 | macas
# Processing Record 45 of Set 11 | ginir
# Processing Record 46 of Set 11 | cheney
# Processing Record 47 of Set 11 | qala
# Processing Record 48 of Set 11 | bamako
# Processing Record 49 of Set 11 | bridlington
# Processing Record 50 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 12 | san rafael
# Processing Record 2 of Set 12 | kankakee
# Processing Record 3 of Set 12 | stromness
# Processing Record 4 of Set 12 | garca
# Processing Record 5 of Set 12 | da nang
# Processing Record 6 of Set 12 | bogen
# Processing Record 7 of Set 12 | greytown
# Processing Record 8 of Set 12 | yulara
# Processing Record 9 of Set 12 | tura
# Processing Record 10 of Set 12 | frontignan
# Processing Record 11 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 13 of Set 12 | macedo de cavaleiros
# Processing Record 14 of Set 12 | meulaboh
# Processing Record 15 of Set 12 | terrasini
# Processing Record 16 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 17 of Set 12 | nenjiang
# Processing Record 18 of Set 12 | wanaka
# Processing Record 19 of Set 12 | sorsk
# Processing Record 20 of Set 12 | bodden town
# Processing Record 21 of Set 12 | birnin kebbi
# Processing Record 22 of Set 12 | bandar-e anzali
# Processing Record 23 of Set 12 | praia da vitoria
# Processing Record 24 of Set 12 | ngunguru
# Processing Record 25 of Set 12 | simi
# Processing Record 26 of Set 12 | lucapa
# Processing Record 27 of Set 12 | estacion coahuila
# Processing Record 28 of Set 12 | fuyang
# Processing Record 29 of Set 12 | saint anthony
# Processing Record 30 of Set 12 | zalantun
# Processing Record 31 of Set 12 | sur
# Processing Record 32 of Set 12 | takoradi
# Processing Record 33 of Set 12 | osypenko
# Processing Record 34 of Set 12 | springdale
# Processing Record 35 of Set 12 | medea
# Processing Record 36 of Set 12 | jeremoabo
# Processing Record 37 of Set 12 | iqaluit
# Processing Record 38 of Set 12 | antofagasta
# Processing Record 39 of Set 12 | dzilam gonzalez
# Processing Record 40 of Set 12 | russell
# Processing Record 41 of Set 12 | eirunepe
# Processing Record 42 of Set 12 | hobyo
# Processing Record 43 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 12 | tiznit
# Processing Record 45 of Set 12 | vanavara
# Processing Record 46 of Set 12 | zyryanka
# Processing Record 47 of Set 12 | aloleng
# Processing Record 48 of Set 12 | ankang
# Processing Record 49 of Set 12 | camana
# Processing Record 50 of Set 12 | summerville
# Processing Record 1 of Set 13 | san martin
# Processing Record 2 of Set 13 | la ronge
# Processing Record 3 of Set 13 | neuquen
# Processing Record 4 of Set 13 | hammerfest
# Processing Record 5 of Set 13 | progreso
# Processing Record 6 of Set 13 | lasa
# Processing Record 7 of Set 13 | copiapo
# Processing Record 8 of Set 13 | sarany
# Processing Record 9 of Set 13 | waipawa
# Processing Record 10 of Set 13 | gogrial
# Processing Record 11 of Set 13 | mizque
# Processing Record 12 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 13 of Set 13 | chaplynka
# Processing Record 14 of Set 13 | burica
# City not found. Skipping...
# Processing Record 15 of Set 13 | lakeway
# Processing Record 16 of Set 13 | solnechnyy
# Processing Record 17 of Set 13 | lancaster
# Processing Record 18 of Set 13 | nhulunbuy
# Processing Record 19 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 13 | aluksne
# Processing Record 21 of Set 13 | krasnoarmeysk
# Processing Record 22 of Set 13 | anloga
# Processing Record 23 of Set 13 | darhan
# Processing Record 24 of Set 13 | gushi
# Processing Record 25 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 13 | zhigansk
# Processing Record 27 of Set 13 | port hawkesbury
# Processing Record 28 of Set 13 | kibondo
# Processing Record 29 of Set 13 | havelock
# Processing Record 30 of Set 13 | bagotville
# Processing Record 31 of Set 13 | stamsund
# City not found. Skipping...
# Processing Record 32 of Set 13 | nizwa
# Processing Record 33 of Set 13 | bertoua
# Processing Record 34 of Set 13 | olmos
# Processing Record 35 of Set 13 | katiola
# Processing Record 36 of Set 13 | susangerd
# Processing Record 37 of Set 13 | simplicio mendes
# Processing Record 38 of Set 13 | dhidhdhoo
# Processing Record 39 of Set 13 | ayios matthaios
# City not found. Skipping...
# Processing Record 40 of Set 13 | tailai
# Processing Record 41 of Set 13 | pauini
# Processing Record 42 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 43 of Set 13 | masterton
# Processing Record 44 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 13 | chkalovskoye
# Processing Record 46 of Set 13 | ogulin
# Processing Record 47 of Set 13 | chikwawa
# Processing Record 48 of Set 13 | shimanovsk
# Processing Record 49 of Set 13 | rawson
# Processing Record 50 of Set 13 | pampa
# Processing Record 1 of Set 14 | verkh-usugli
# Processing Record 2 of Set 14 | solwezi
# Processing Record 3 of Set 14 | bluefield
# Processing Record 4 of Set 14 | flin flon
# Processing Record 5 of Set 14 | baracoa
# Processing Record 6 of Set 14 | bafq
# Processing Record 7 of Set 14 | cody
# Processing Record 8 of Set 14 | faro
# Processing Record 9 of Set 14 | varca
# Processing Record 10 of Set 14 | kavaratti
# Processing Record 11 of Set 14 | radyvyliv
# Processing Record 12 of Set 14 | garissa
# Processing Record 13 of Set 14 | jalu
# Processing Record 14 of Set 14 | niimi
# Processing Record 15 of Set 14 | paulo afonso
# Processing Record 16 of Set 14 | kailua
# Processing Record 17 of Set 14 | vredendal
# Processing Record 18 of Set 14 | ust-maya
# Processing Record 19 of Set 14 | cap malheureux
# Processing Record 20 of Set 14 | challapata
# Processing Record 21 of Set 14 | roald
# Processing Record 22 of Set 14 | pipri
# Processing Record 23 of Set 14 | saint-denis
# Processing Record 24 of Set 14 | yining
# Processing Record 25 of Set 14 | kendari
# Processing Record 26 of Set 14 | iberia
# Processing Record 27 of Set 14 | lyuban
# Processing Record 28 of Set 14 | ayorou
# Processing Record 29 of Set 14 | shubarshi
# Processing Record 30 of Set 14 | caravelas
# Processing Record 31 of Set 14 | port-cartier
# Processing Record 32 of Set 14 | millinocket
# Processing Record 33 of Set 14 | ust-ishim
# Processing Record 34 of Set 14 | pyapon
# Processing Record 35 of Set 14 | amboasary
# Processing Record 36 of Set 14 | warrnambool
# Processing Record 37 of Set 14 | jardim
# Processing Record 38 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 14 | lufilufi
# Processing Record 40 of Set 14 | honiara
# Processing Record 41 of Set 14 | werda
# Processing Record 42 of Set 14 | peleduy
# Processing Record 43 of Set 14 | constantine
# Processing Record 44 of Set 14 | carmen
# Processing Record 45 of Set 14 | puerto colombia
# Processing Record 46 of Set 14 | antalaha
# Processing Record 47 of Set 14 | bilibino
# Processing Record 48 of Set 14 | ukmerge
# Processing Record 49 of Set 14 | sibolga
# Processing Record 50 of Set 14 | gotsu
# Processing Record 1 of Set 15 | hauterive
# Processing Record 2 of Set 15 | bolgar
# Processing Record 3 of Set 15 | kieta
# Processing Record 4 of Set 15 | kathmandu
# Processing Record 5 of Set 15 | saint-pierre
# Processing Record 6 of Set 15 | kodinar
# Processing Record 7 of Set 15 | sisimiut
# Processing Record 8 of Set 15 | barra da estiva
# Processing Record 9 of Set 15 | nouadhibou
# Processing Record 10 of Set 15 | johi
# Processing Record 11 of Set 15 | tarata
# Processing Record 12 of Set 15 | tefe
# Processing Record 13 of Set 15 | meiganga
# Processing Record 14 of Set 15 | hambantota
# Processing Record 15 of Set 15 | benghazi
# Processing Record 16 of Set 15 | hulan ergi
# Processing Record 17 of Set 15 | killybegs
# Processing Record 18 of Set 15 | mango
# Processing Record 19 of Set 15 | usinsk
# Processing Record 20 of Set 15 | palembang
# Processing Record 21 of Set 15 | adre
# Processing Record 22 of Set 15 | pomabamba
# Processing Record 23 of Set 15 | beyneu
# Processing Record 24 of Set 15 | derzhavinsk
# Processing Record 25 of Set 15 | hailar
# Processing Record 26 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 15 | inverell
# Processing Record 28 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 15 | gravelbourg
# Processing Record 30 of Set 15 | shu
# Processing Record 31 of Set 15 | muskogee
# Processing Record 32 of Set 15 | bindura
# Processing Record 33 of Set 15 | warrington
# Processing Record 34 of Set 15 | salisbury
# Processing Record 35 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 15 | guarapari
# Processing Record 37 of Set 15 | livingston
# Processing Record 38 of Set 15 | uni
# Processing Record 39 of Set 15 | dingle
# Processing Record 40 of Set 15 | ihosy
# Processing Record 41 of Set 15 | same
# Processing Record 42 of Set 15 | lima
# Processing Record 43 of Set 15 | ondjiva
# Processing Record 44 of Set 15 | omsukchan
# Processing Record 45 of Set 15 | huarmey
# Processing Record 46 of Set 15 | tavistock
# Processing Record 47 of Set 15 | uyuni
# Processing Record 48 of Set 15 | yeovil
# Processing Record 49 of Set 15 | xifeng
# Processing Record 50 of Set 15 | charters towers
# Processing Record 1 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 16 | methoni
# Processing Record 3 of Set 16 | syntul
# Processing Record 4 of Set 16 | dawlatabad
# Processing Record 5 of Set 16 | korla
# Processing Record 6 of Set 16 | ulaangom
# Processing Record 7 of Set 16 | quartucciu
# Processing Record 8 of Set 16 | constitucion
# Processing Record 9 of Set 16 | ahipara
# Processing Record 10 of Set 16 | monte carmelo
# Processing Record 11 of Set 16 | rockland
# ----------------------------
# Data Retriecal Complete
# ----------------------------

# %%
# confirm count

len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Leningradskiy      RU  69.3833  178.4167     35.73        82          25
# 1        Samarai      PG -10.6167  150.6667     81.37        65          63
# 2         Sabang      ID   5.8933   95.3214     83.37        75         100
# 3           Lebu      CL -37.6167  -73.6500     57.31        95         100
# 4         Barrow      US  71.2906 -156.7887     35.62        69          90
# 5          Vaini      TO -21.2000 -175.2000     78.96        73          20
# 6      Busselton      AU -33.6500  115.3333     61.05        63         100
# 7        Durazno      UY -33.4131  -56.5006     49.95        93           0
# 8     Phan Thiet      VN  10.9333  108.1000     83.26        74         100
# 9        Ushuaia      AR -54.8000  -68.3000     29.86        86          75
#
#    Wind Speed Current Description
# 0        6.53    scattered clouds
# 1       14.65       broken clouds
# 2       19.30     overcast clouds
# 3        6.51          light rain
# 4       13.80     overcast clouds
# 5       11.50          few clouds
# 6       17.05     overcast clouds
# 7        6.91           clear sky
# 8        2.55     overcast clouds
# 9       18.41          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
